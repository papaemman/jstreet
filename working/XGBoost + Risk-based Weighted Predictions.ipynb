# %% [markdown]
# # XGBoost + Risk-based Weighted Predictions

# %% [markdown]
# **Trick:** Adjusted predictions based on classifier certainty

# %%
# Load modules
import numpy as np
import pandas as pd
import xgboost as xgb
import janestreet

# %%
import gc # garbage collection
import joblib
from tqdm import tqdm

# %%
# Test packages
print(np.__version__)
print(pd.__version__)
print(xgb.__version__)


assert np.__version__ == '1.18.5'
assert pd.__version__ == '1.1.4'
assert xgb.__version__ == '1.2.1'
# Out:
# 1.18.5
# 1.1.4
# 1.2.1

# %% [markdown]
# ## Load dataset

# %%
# Load data
train = pd.read_csv('../input/jane-street-market-prediction/train.csv')
print(f'Done loading data. Train shape is {train.shape}')
# Out:
# Done loading data. Train shape is (2390491, 138)

# %%
train.head()
# Out:
#    date     weight    resp_1    resp_2    resp_3    resp_4      resp  \
# 0     0   0.000000  0.009916  0.014079  0.008773  0.001390  0.006270
# 1     0  16.673515 -0.002828 -0.003226 -0.007319 -0.011114 -0.009792
# 2     0   0.000000  0.025134  0.027607  0.033406  0.034380  0.023970
# 3     0   0.000000 -0.004730 -0.003273 -0.000461 -0.000476 -0.003200
# 4     0   0.138531  0.001252  0.002165 -0.001215 -0.006219 -0.002604
#
#    feature_0  feature_1  feature_2  ...  feature_121  feature_122  \
# 0          1  -1.872746  -2.191242  ...          NaN     1.168391
# 1         -1  -1.349537  -1.704709  ...          NaN    -1.178850
# 2         -1   0.812780  -0.256156  ...          NaN     6.115747
# 3         -1   1.174378   0.344640  ...          NaN     2.838853
# 4          1  -3.172026  -3.093182  ...          NaN     0.344850
#
#    feature_123  feature_124  feature_125  feature_126  feature_127  \
# 0     8.313583     1.782433    14.018213     2.653056    12.600292
# 1     1.777472    -0.915458     2.831612    -1.417010     2.297459
# 2     9.667908     5.542871    11.671595     7.281757    10.060014
# 3     0.499251     3.033732     1.513488     4.397532     1.266037
# 4     4.101145     0.614252     6.623456     0.800129     5.233243
#
#    feature_128  feature_129  ts_id
# 0     2.301488    11.445807      0
# 1    -1.304614     1.898684      1
# 2     6.638248     9.427299      2
# 3     3.856384     1.013469      3
# 4     0.362636     3.926633      4
#
# [5 rows x 138 columns]

# %%
# For training only look at data that has non-zero weight
train = train[train.weight != 0]

# %% [markdown]
# ## Define experiment settings

# %%
# Settings
NAN_VALUE = -999
FEATURES = [c for c in train.columns if 'feature' in c]
TARGET = 'resp'
MAX_WEIGHT = train.weight.max()

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# The same preprocessing steps must be done to test dataset too.

# %%
# Split into X and y
X = train.loc[:, FEATURES].fillna(NAN_VALUE)

# %%
# Create targets
y = (train.loc[:, TARGET] > 0).astype(int)

# %%
# Clear memory
del train
gc.collect()
# Out:
# 100

# %% [markdown]
# ## Train model

# %%
# Parameters from: https://www.kaggle.com/hamditarek/market-prediction-xgboost-with-gpu-fit-in-1min
model = xgb.XGBClassifier(n_estimators=500,
                          max_depth=11,
                          learning_rate=0.05,
                          subsample=0.9,
                          colsample_bytree=0.7,
                          missing=NAN_VALUE,
                          random_state=2020,
                          tree_method='hist',
                          n_jobs = 10, verbosity = 2)
model.fit(X, y)
print('Finished training model')
# Out:
# [19:55:41] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:55
extra nodes, 0 pruned nodes, max_depth=11
# [19:57:37] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:37] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1864 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:37] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:38] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2166 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:38] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:39] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2150 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:39] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2148 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:40] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:40] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1814 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:40] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2230 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:41] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:41] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1760 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:41] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1558 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:42] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2128 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:43] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2396 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:44] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1566 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:44] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1866 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:45] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1848 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:45] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2128 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:46] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1962 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:47] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2284 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:47] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2346 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:48] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2702 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:49] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1868 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:49] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2004 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:50] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1808 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:51] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2424 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:51] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2414 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:52] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1578 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:53] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2004 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:53] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2406 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:54] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1794 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:55] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1650 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:55] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2334 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:56] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1792 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:56] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1620 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:57] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1832 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:58] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2130 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:58] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:57:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2004 extra nodes, 0 pruned nodes, max_depth=11
# [19:57:59] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:58:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2210 extra nodes, 0 pruned nodes, max_depth=11
# [19:58:00] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [19:58:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2046 extra nodes, 0 pruned nodes, max_depth=11
# [19:58:00] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# ...
# [20:00:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2714 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:42] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:42] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2118 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:43] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:43] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2620 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:43] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1738 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:44] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:44] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1786 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:45] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:45] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2542 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:45] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1914 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:46] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:46] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2028 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:47] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:47] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2460 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:47] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 3000 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:48] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2660 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:49] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:49] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1854 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:50] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:50] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1624 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:50] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2466 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:51] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:51] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1598 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:52] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:52] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2558 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:52] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2286 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:53] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:53] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1352 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:53] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:54] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1438 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:54] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1816 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:55] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:55] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1610 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:55] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:56] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2190 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:56] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2198 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:57] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:57] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2296 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:57] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:58] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2880 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:58] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1520 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:59] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:00:59] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1616 extra nodes, 0 pruned nodes, max_depth=11
# [20:00:59] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1778 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:00] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:00] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2258 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:00] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:01] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2642 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:01] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1690 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:02] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:02] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2186 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:02] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:03] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2206 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:03] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2106 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:04] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:04] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2396 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:05] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:05] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1494 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:05] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2170 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:06] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:06] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1984 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:06] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1596 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:07] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:07] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2350 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:07] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:08] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2256 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:08] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1636 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:09] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:09] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2514 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:09] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:10] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2484 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:10] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2556 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:11] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:11] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1858 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:12] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:12] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2278 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:12] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:13] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2466 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:13] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1976 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:14] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:14] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2302 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:14] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:15] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2612 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:15] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2442 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:16] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:16] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1932 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:17] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:17] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2166 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:17] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:18] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2808 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:18] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2656 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:19] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:19] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1464 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:19] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:20] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2492 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:20] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 1902 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:21] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:21] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2062 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:21] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:22] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2054 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:22] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2724 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:23] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:23] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2010 extra nodes, 0 pruned nodes, max_depth=11
# [20:01:23] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# [20:01:24] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 2472 extra nodes, 0 pruned nodes, max_depth=11
# Finished training model

# %%
# save model to file
joblib.dump(model, "../models/xgboost_v0.joblib.dat")
# Out:
# [20:01:24] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# ['../models/xgboost_v0.joblib.dat']

# %%
# Clear memory
del X, y
gc.collect()
# Out:
# 56

# %% [markdown]
# ## Predict

# %%
# load model from file
model = joblib.load("../models/xgboost_v0.joblib.dat")

# %%
# Create submission using time-series API (from janestreet module)
env = janestreet.make_env()
iter_test = env.iter_test()

for (test_df, sample_prediction_df) in tqdm(iter_test):    
    test_weight = test_df.iloc[0].weight
    if test_weight > 0:
        proba = model.predict_proba(test_df.loc[:, FEATURES].fillna(NAN_VALUE))[0, 1]
        sample_prediction_df.action = 1 if proba > 0.49 else 0
    else:
        sample_prediction_df.action = 0
    env.predict(sample_prediction_df)
# Out:
# 23it [00:00,  6.16it/s]
# [20:01:25] INFO: ../src/gbm/gbtree.cc:169: Tree method is selected to be 'hist', which uses a single updater grow_quantile_histmaker.
# 15219it [03:18, 76.76it/s]
